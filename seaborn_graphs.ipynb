# %% [markdown]
# # Plots with Seaborn

# %%
import pandas as pd
import seaborn as sns
# Apply the default theme
sns.set_theme()

# %% [markdown]
# ## RELPLOT

# %%
data_usa = pd.read_csv('data_USA_2002_2022.csv')
columns_data = data_usa.columns
print(columns_data)
#data_usa
# Out:
# Index(['DATE', 'UNRATE(%)', 'CONSUMER CONF INDEX', 'PPI-CONST MAT.',
#        'CPIALLITEMS', 'INFLATION(%)', 'MORTGAGE INT. MONTHLY AVG(%)',
#        'MED HOUSEHOLD INCOME', 'CORP. BOND YIELD(%)', 'MONTHLY HOME SUPPLY',
#        '% SHARE OF WORKING POPULATION', 'GDP PER CAPITA', 'QUARTERLY REAL GDP',
#        'QUARTERLY GDP GROWTH RATE (%)', 'CSUSHPISA'],
#       dtype='object')

# %%
sns.lineplot(
    data=data_usa,
    x="DATE", y="UNRATE(%)",
)
# Out:
# <AxesSubplot: xlabel='DATE', ylabel='UNRATE(%)'>
